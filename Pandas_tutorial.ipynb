# %% [markdown]
# # What Is Python Pandas?
#
# Pandas is a powerful, open-source data analysis and manipulation library for Python. It provides data structures and functions needed to work on structured data seamlessly and efficiently. Developed by Wes McKinney in 2008, Pandas is built on top of the NumPy library and is widely used for data wrangling, cleaning, analysis, and visualization.

# %% [markdown]
# # What Is Pandas Used For?
#
# Pandas is extensively used for:
#
#     Data Cleaning: Handling missing values, duplications, and incorrect data formats.
#     Data Manipulation: Filtering, transforming, and merging datasets.
#     Data Analysis: Performing statistical analysis and aggregations.
#     Data Visualization: Creating plots and charts to visualize data trends and patterns.
#     Time Series Analysis: Handling and manipulating time series data.

# %%
import pandas as pd

# %% [markdown]
# ### read .csv files in pandas

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df_no_header = pd.read_csv("diabetes.csv", header=None)
df_no_header
# Out:
#                0        1              2              3        4     5  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#                             6    7        8
# 0    DiabetesPedigreeFunction  Age  Outcome
# 1                       0.627   50        1
# 2                       0.351   31        0
# 3                       0.672   32        1
# 4                       0.167   21        0
# ..                        ...  ...      ...
# 764                     0.171   63        0
# 765                      0.34   27        0
# 766                     0.245   30        0
# 767                     0.349   47        1
# 768                     0.315   23        0
#
# [769 rows x 9 columns]

# %% [markdown]
# ### output pandas dataframe to a .csv file

# %%
df.to_csv("diabetes_out.csv", index=False, header=False)

# %%
df.to_csv("diabetes_out_v2.csv", index=False)

# %%
df.to_csv("diabetes_out_v3.csv")

# %%
df_v2 = pd.read_csv('diabetes_out.csv')
df_v2
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
df_v3 = pd.read_csv('diabetes_out.csv', header=None)
df_v3
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[2]
# Out:
# Pregnancies                   8.000
# Glucose                     183.000
# BloodPressure                64.000
# SkinThickness                 0.000
# Insulin                       0.000
# BMI                          23.300
# DiabetesPedigreeFunction      0.672
# Age                          32.000
# Outcome                       1.000
# Name: 2, dtype: float64

# %%
df.loc[2]['BloodPressure']
# Out:
# 64.0

# %%
df.loc[2][2]
# Out:
# 64.0

# %%
df.iloc[2]
# Out:
# Pregnancies                   8.000
# Glucose                     183.000
# BloodPressure                64.000
# SkinThickness                 0.000
# Insulin                       0.000
# BMI                          23.300
# DiabetesPedigreeFunction      0.672
# Age                          32.000
# Outcome                       1.000
# Name: 2, dtype: float64

# %%
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
type(df['BloodPressure'])
# Out:
# pandas.core.series.Series

# %%
type(df.loc[2][2])
# Out:
# numpy.float64

# %%
type(df_v2.iloc[4][4])
# Out:
# numpy.float64

# %%
df_v3 = pd.read_csv('diabetes_out_v2.csv', header=None)
df_v3
# Out:
#                0        1              2              3        4     5  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#                             6    7        8
# 0    DiabetesPedigreeFunction  Age  Outcome
# 1                       0.627   50        1
# 2                       0.351   31        0
# 3                       0.672   32        1
# 4                       0.167   21        0
# ..                        ...  ...      ...
# 764                     0.171   63        0
# 765                      0.34   27        0
# 766                     0.245   30        0
# 767                     0.349   47        1
# 768                     0.315   23        0
#
# [769 rows x 9 columns]

# %%
type(df_v3.iloc[4][5])
# Out:
# str

# %% [markdown]
# ### head() and tail() method

# %%
df.head(15)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# 12           10      139             80              0        0  27.1
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1
# 5                      0.201   30        0
# 6                      0.248   26        1
# 7                      0.134   29        0
# 8                      0.158   53        1
# 9                      0.232   54        1
# 10                     0.191   30        0
# 11                     0.537   34        1
# 12                     1.441   57        0
# 13                     0.398   59        1
# 14                     0.587   51        1

# %%
df.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# ### describe() method

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.describe(percentiles=[0.3, 0.5, 0.7])
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 30%       1.000000  102.000000      64.000000       8.200000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 70%       5.000000  134.000000      78.000000      31.000000  106.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 30%     28.200000                  0.259000   25.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 70%     35.490000                  0.563700   38.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ###### You can also isolate specific data types in your summary output by using the include argument. Here, for example, we’re only summarizing the columns with the integer data type.

# %%
df.describe(include=[int])
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               Age     Outcome
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
df.describe(exclude=[int])
# Out:
#               BMI  DiabetesPedigreeFunction
# count  768.000000                768.000000
# mean    31.992578                  0.471876
# std      7.884160                  0.331329
# min      0.000000                  0.078000
# 25%     27.300000                  0.243750
# 50%     32.000000                  0.372500
# 75%     36.600000                  0.626250
# max     67.100000                  2.420000

# %% [markdown]
# ### Understanding data using .info()
#
# The .info() method is a quick way to look at the data types, missing values, and data size of a DataFrame. Here, we’re setting the show_counts argument to True, which gives a few over the total non-missing values in each column. We’re also setting memory_usage to True, which shows the total memory usage of the DataFrame elements. When verbose is set to True, it prints the full summary from .info().

# %%
df.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ### Understanding your data using .shape
#
# The number of rows and columns of a DataFrame can be identified using the .shape attribute of the DataFrame. It returns a tuple (row, column) and can be indexed to get only rows, and only columns count as output.

# %%
print(df.shape) # Get the number of rows and columns
print(df.shape[0]) # Get the number of rows only
print(df.shape[1]) # Get the number of columns only
# Out:
# (768, 9)
# 768
# 9

# %% [markdown]
# ### get columnnames

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# ### Checking for missing values in pandas with .isnull()
#
# The sample DataFrame does not have any missing values. Let's introduce a few to make things interesting. The .copy() method makes a copy of the original DataFrame. This is done to ensure that any changes to the copy don’t reflect in the original DataFrame. Using .loc (to be discussed later), you can set rows two to five of the Pregnancies column to NaN values, which denote missing values.

# %%
df2 = df.copy()
df2.loc[2:5,'Pregnancies'] = None
print(df.head(7))
print(df2.head(7))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72             35        0  33.6
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
# 5          NaN      116             74              0        0  25.6
# 6          3.0       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1

# %%
df2.isnull().head(7)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0        False    False          False          False    False  False
# 1        False    False          False          False    False  False
# 2         True    False          False          False    False  False
# 3         True    False          False          False    False  False
# 4         True    False          False          False    False  False
# 5         True    False          False          False    False  False
# 6        False    False          False          False    False  False
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     False  False    False
# 1                     False  False    False
# 2                     False  False    False
# 3                     False  False    False
# 4                     False  False    False
# 5                     False  False    False
# 6                     False  False    False

# %% [markdown]
# ###### Given it's often more useful to know how much missing data you have, you can combine .isnull() with .sum() to count the number of nulls in each column.

# %%
df2.isnull().sum()
# Out:
# Pregnancies                 4
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ###### You can also do a double sum to get the total number of nulls in the DataFrame.

# %%
df2.isnull().sum().sum()
# Out:
# 4

# %%
df_trial = pd.DataFrame()
df_trial
df_trial
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Isolating one column

# %%
df_5 = pd.DataFrame()

print(df_5)
df_5['Outcome_1'] = [1, 4, 4, 5, 6]


print(df_5)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#    Outcome_1
# 0          1
# 1          4
# 2          4
# 3          5
# 4          6

# %%
df_trial_1 = pd.DataFrame()

state_list = ['Maharashtra', 'Odisha', 'Bihar']
capital_list = ['Mumbai', 'Bhubaneshwar', 'Patna']

GDP_list = [1000, 800, 800]

df_trial_1[['State_1', 'capital_list_1', 'GDP_list_1']] = [state_list, capital_list, GDP_list]
df_trial_1
# Out:
#        State_1 capital_list_1 GDP_list_1
# 0  Maharashtra         Odisha      Bihar
# 1       Mumbai   Bhubaneshwar      Patna
# 2         1000            800        800

# %%
state_dict = {'State': state_list, 'capital_list': capital_list, 'GDP_list': GDP_list}

df_trial_2 = pd.DataFrame(state_dict)

df_trial_2
# Out:
#          State  capital_list  GDP_list
# 0  Maharashtra        Mumbai      1000
# 1       Odisha  Bhubaneshwar       800
# 2        Bihar         Patna       800

# %%
state_details  = [state_list, capital_list, GDP_list]

df_trial_3 = pd.DataFrame(state_details, columns=['State', 'capital_list', 'GDP_list', ])
df_trial_3
# Out:
#          State  capital_list GDP_list
# 0  Maharashtra        Odisha    Bihar
# 1       Mumbai  Bhubaneshwar    Patna
# 2         1000           800      800

# %%
state_details
# Out:
# [['Maharashtra', 'Odisha', 'Bihar'],
#  ['Mumbai', 'Bhubaneshwar', 'Patna'],
#  [1000, 800, 800]]

# %%
df_trial_1
# Out:
#        State_1 capital_list_1 GDP_list_1
# 0  Maharashtra         Odisha      Bihar
# 1       Mumbai   Bhubaneshwar      Patna
# 2         1000            800        800

# %% [markdown]
# ### Isolating two or more columns using

# %%
df_partial = df[['Pregnancies', 'Outcome']]

print(df_partial)

# print(df_partial)

df_partial['Pregnancies'].iloc[0] = 2

print(df_partial)

# print(df)
# Out:
#      Pregnancies  Outcome
# 0              6        1
# 1              1        0
# 2              8        1
# 3              1        0
# 4              0        1
# ..           ...      ...
# 763           10        0
# 764            2        0
# 765            5        0
# 766            1        1
# 767            1        0
#
# [768 rows x 2 columns]
#      Pregnancies  Outcome
# 0              2        1
# 1              1        0
# 2              8        1
# 3              1        0
# 4              0        1
# ..           ...      ...
# 763           10        0
# 764            2        0
# 765            5        0
# 766            1        1
# 767            1        0
#
# [768 rows x 2 columns]
# C:\Users\IITM\AppData\Local\Temp\ipykernel_19836\3981150618.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_partial['Pregnancies'].iloc[0] = 2

# %% [markdown]
# ### Isolating one row

# %%
df[df.index==1]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 1                     0.351   31        0

# %%
df[df['Pregnancies'] > 4]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 765            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 2                       0.672   32        1
# 5                       0.201   30        0
# 7                       0.134   29        0
# 9                       0.232   54        1
# ..                        ...  ...      ...
# 759                     0.278   66        1
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 765                     0.245   30        0
#
# [276 rows x 9 columns]

# %%
df.iloc[1]
# Out:
# Pregnancies                  1.000
# Glucose                     85.000
# BloodPressure               66.000
# SkinThickness               29.000
# Insulin                      0.000
# BMI                         26.600
# DiabetesPedigreeFunction     0.351
# Age                         31.000
# Outcome                      0.000
# Name: 1, dtype: float64

# %% [markdown]
# ### Isolating two or more rows

# %%
df[df.index.isin(range(100,110))]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 100            1      163             72              0        0  39.0
# 101            1      151             60              0        0  26.1
# 102            0      125             96              0        0  22.5
# 103            1       81             72             18       40  26.6
# 104            2       85             65              0        0  39.6
# 105            1      126             56             29      152  28.7
# 106            1       96            122              0        0  22.4
# 107            4      144             58             28      140  29.5
# 108            3       83             58             31       18  34.3
# 109            0       95             85             25       36  37.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 100                     1.222   33        1
# 101                     0.179   22        0
# 102                     0.262   21        0
# 103                     0.283   24        0
# 104                     0.930   27        0
# 105                     0.801   21        0
# 106                     0.207   27        0
# 107                     0.287   37        0
# 108                     0.336   25        0
# 109                     0.247   24        1

# %%
trial_index = [103, 107, 108]

df[df.index.isin(trial_index)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 103            1       81             72             18       40  26.6
# 107            4      144             58             28      140  29.5
# 108            3       83             58             31       18  34.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 103                     0.283   24        0
# 107                     0.287   37        0
# 108                     0.336   25        0

# %% [markdown]
# ### Using .loc[ ] and .iloc[ ]  to fetch rows
#
# You can fetch specific rows by labels or conditions using .loc[] and .iloc[] ("location" and "integer location"). .loc[] uses a label to point to a row, column or cell, whereas .iloc[] uses the numeric position. To understand the difference between the two, let’s modify the index of df2 created earlier.
#
#
# The below example returns a pandas Series instead of a DataFrame. The 1 represents the row index (label), whereas the 1 in .iloc[] is the row position (first row).

# %%
preg_lst = [2, 5]

df_partial_1 = df[df['Pregnancies'] < 3]
print(len(df_partial_1))
# Out:
# 349

# %%
# df2.index = range(1,769)
df2.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
df2.loc[1]
# Out:
# Pregnancies                  1.000
# Glucose                     85.000
# BloodPressure               66.000
# SkinThickness               29.000
# Insulin                      0.000
# BMI                         26.600
# DiabetesPedigreeFunction     0.351
# Age                         31.000
# Outcome                      0.000
# Name: 1, dtype: float64

# %%
df.iloc[1]
# Out:
# Pregnancies                  1.000
# Glucose                     85.000
# BloodPressure               66.000
# SkinThickness               29.000
# Insulin                      0.000
# BMI                         26.600
# DiabetesPedigreeFunction     0.351
# Age                         31.000
# Outcome                      0.000
# Name: 1, dtype: float64

# %%
df2.loc[100:110]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 100          1.0      163             72              0        0  39.0
# 101          1.0      151             60              0        0  26.1
# 102          0.0      125             96              0        0  22.5
# 103          1.0       81             72             18       40  26.6
# 104          2.0       85             65              0        0  39.6
# 105          1.0      126             56             29      152  28.7
# 106          1.0       96            122              0        0  22.4
# 107          4.0      144             58             28      140  29.5
# 108          3.0       83             58             31       18  34.3
# 109          0.0       95             85             25       36  37.4
# 110          3.0      171             72             33      135  33.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 100                     1.222   33        1
# 101                     0.179   22        0
# 102                     0.262   21        0
# 103                     0.283   24        0
# 104                     0.930   27        0
# 105                     0.801   21        0
# 106                     0.207   27        0
# 107                     0.287   37        0
# 108                     0.336   25        0
# 109                     0.247   24        1
# 110                     0.199   24        1

# %%
df2.loc[[100, 200, 300]]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 100          1.0      163             72              0        0  39.0
# 200          0.0      113             80             16        0  31.0
# 300          0.0      167              0              0        0  32.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 100                     1.222   33        1
# 200                     0.874   21        0
# 300                     0.839   30        1

# %%
df2.iloc[[100, 200, 300]]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 100          1.0      163             72              0        0  39.0
# 200          0.0      113             80             16        0  31.0
# 300          0.0      167              0              0        0  32.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 100                     1.222   33        1
# 200                     0.874   21        0
# 300                     0.839   30        1

# %%
df2.loc[100:110, ['Pregnancies', 'Glucose', 'BloodPressure']]
# Out:
#      Pregnancies  Glucose  BloodPressure
# 100          1.0      163             72
# 101          1.0      151             60
# 102          0.0      125             96
# 103          1.0       81             72
# 104          2.0       85             65
# 105          1.0      126             56
# 106          1.0       96            122
# 107          4.0      144             58
# 108          3.0       83             58
# 109          0.0       95             85
# 110          3.0      171             72

# %%
df2.iloc[100:110, :-3]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 100          1.0      163             72              0        0  39.0
# 101          1.0      151             60              0        0  26.1
# 102          0.0      125             96              0        0  22.5
# 103          1.0       81             72             18       40  26.6
# 104          2.0       85             65              0        0  39.6
# 105          1.0      126             56             29      152  28.7
# 106          1.0       96            122              0        0  22.4
# 107          4.0      144             58             28      140  29.5
# 108          3.0       83             58             31       18  34.3
# 109          0.0       95             85             25       36  37.4

# %% [markdown]
# ### Conditional slicing (that fits certain conditions)

# %%
df[df.BloodPressure == 122]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 106            1       96            122              0        0  22.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 106                     0.207   27        0

# %%
df.loc[df['BloodPressure'] > 100, ['Pregnancies', 'Glucose', 'BloodPressure']]
# Out:
#      Pregnancies  Glucose  BloodPressure
# 43             9      171            110
# 84             5      137            108
# 106            1       96            122
# 177            0      129            110
# 207            5      162            104
# 362            5      103            108
# 369            1      133            102
# 440            0      189            104
# 549            4      189            110
# 658           11      127            106
# 662            8      167            106
# 672           10       68            106
# 691           13      158            114

# %% [markdown]
# ### Dropping missing values

# %%
df3 = df2.copy()

print('Before dropping NaN values', df3.shape)
df3 = df3.dropna()
print('After dropping NaN values', df3.shape)

df4 = df2.copy()
df4 = df4.dropna(axis=1)
print(df4.shape)
# Out:
# Before dropping NaN values (768, 9)
# After dropping NaN values (764, 9)
# (768, 8)

# %%
df3 ### check index
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72             35        0  33.6
# 1            1.0       85             66             29        0  26.6
# 6            3.0       78             50             32       88  31.0
# 7           10.0      115              0              0        0  35.3
# 8            2.0      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76             48      180  32.9
# 764          2.0      122             70             27        0  36.8
# 765          5.0      121             72             23      112  26.2
# 766          1.0      126             60              0        0  30.1
# 767          1.0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 6                       0.248   26        1
# 7                       0.134   29        0
# 8                       0.158   53        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [764 rows x 9 columns]

# %%
df3 = df2.copy()
df3.dropna(inplace=True, axis=1)
df3.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Replacing missing values

# %%
df3 = df2.copy()
# Get the mean of Pregnancies
mean_value = df3['Pregnancies'].mean()
# Fill missing values using .fillna()
df3 = df3.fillna(mean_value)
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0       6.000000      148             72             35        0  33.6
# 1       1.000000       85             66             29        0  26.6
# 2       3.846859      183             64              0        0  23.3
# 3       3.846859       89             66             23       94  28.1
# 4       3.846859      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763    10.000000      101             76             48      180  32.9
# 764     2.000000      122             70             27        0  36.8
# 765     5.000000      121             72             23      112  26.2
# 766     1.000000      126             60              0        0  30.1
# 767     1.000000       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ### Dealing with Duplicate Data

# %%
df3 = pd.concat([df2[1:5], df2[1:5]])
print(df3.shape)
df3
# Out:
# (8, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df3 = df3.drop_duplicates()
print(df3.shape)
df3
# Out:
# (4, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Renaming columns

# %%
df3.rename(columns = {'DiabetesPedigreeFunction':'DPF'}, inplace = True)
df3.head()
# Out:
# C:\Users\IITM\AppData\Local\Temp\ipykernel_19836\1895293643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.rename(columns = {'DiabetesPedigreeFunction':'DPF'}, inplace = True)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI    DPF  \
# 1          1.0       85             66             29        0  26.6  0.351
# 2          NaN      183             64              0        0  23.3  0.672
# 3          NaN       89             66             23       94  28.1  0.167
# 4          NaN      137             40             35      168  43.1  2.288
#
#    Age  Outcome
# 1   31        0
# 2   32        1
# 3   21        0
# 4   33        1

# %% [markdown]
# ### mean, mode, median

# %%
df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
df['Glucose'].mean()
# Out:
# 120.89453125

# %%
df.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
df.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %% [markdown]
# ### Create new columns based on existing columns

# %%
df2['Glucose_Insulin_Ratio'] = df2['Glucose']/df2['Insulin']
df2.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72             35        0  33.6
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Glucose_Insulin_Ratio
# 0                     0.627   50        1                    inf
# 1                     0.351   31        0                    inf
# 2                     0.672   32        1                    inf
# 3                     0.167   21        0               0.946809
# 4                     2.288   33        1               0.815476

# %% [markdown]
# ### Aggregating data with .groupby() in pandas
#
# pandas lets you aggregate values by grouping them by specific column values. You can do that by combining the .groupby() method with a summary method of your choice. The below code displays the mean of each of the numeric columns grouped by Outcome.

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
df.groupby('Outcome')

# %%
df.groupby(['Pregnancies', 'Outcome']).mean()
# Out:
#                         Glucose  BloodPressure  SkinThickness     Insulin  \
# Pregnancies Outcome
# 0           0        111.945205      69.205479      21.054795   77.561644
#             1        144.236842      63.210526      24.605263   89.578947
# 1           0        104.254717      66.830189      23.047170   84.320755
#             1        143.793103      71.310345      29.517241  151.137931
# 2           0        105.214286      61.940476      20.107143   72.619048
#             1        135.473684      69.052632      28.210526  144.315789
# 3           0        109.604167      65.708333      17.520833   62.020833
#             1        148.444444      68.148148      24.629630  132.666667
# 4           0        117.555556      71.577778      18.422222   78.466667
#             1        139.913043      67.000000      10.913043   51.782609
# 5           0        111.666667      74.666667      17.166667   46.861111
#             1        131.190476      78.857143      17.761905   75.190476
# 6           0        115.352941      66.382353      18.705882   69.029412
#             1        132.375000      72.750000      15.375000   52.000000
# 7           0        121.000000      70.350000      19.350000   72.500000
#             1        148.800000      71.120000      21.040000   94.040000
# 8           0        106.625000      75.312500      12.937500   14.500000
#             1        150.000000      75.090909      20.500000  149.772727
# 9           0        107.000000      70.400000      22.400000   71.200000
#             1        144.944444      82.055556      20.055556   57.555556
# 10          0        117.571429      72.857143      10.571429   25.071429
#             1        125.600000      66.500000      22.900000   48.400000
# 11          0        113.250000      81.000000      10.000000    0.000000
#             1        134.000000      70.285714      28.428571  102.857143
# 12          0        111.000000      80.200000      24.600000   31.800000
#             1        116.750000      71.500000      30.250000  213.500000
# 13          0        117.200000      74.400000      22.000000   50.000000
#             1        133.800000      73.200000      12.600000    5.800000
# 14          1        137.500000      70.000000      27.500000   92.000000
# 15          1        136.000000      70.000000      32.000000  110.000000
# 17          1        163.000000      72.000000      41.000000  114.000000
#
#                            BMI  DiabetesPedigreeFunction        Age
# Pregnancies Outcome
# 0           0        31.727397                  0.457055  27.095890
#             1        39.213158                  0.643368  28.578947
# 1           0        29.616038                  0.451679  25.254717
#             1        37.793103                  0.613759  35.103448
# 2           0        29.679762                  0.479881  25.892857
#             1        34.578947                  0.543737  32.947368
# 3           0        29.231250                  0.358354  28.770833
#             1        32.548148                  0.563333  29.481481
# 4           0        31.255556                  0.410511  30.066667
#             1        33.873913                  0.516478  38.086957
# 5           0        31.100000                  0.359278  39.416667
#             1        36.780952                  0.460095  38.380952
# 6           0        29.591176                  0.433294  37.147059
#             1        31.775000                  0.421500  44.000000
# 7           0        29.975000                  0.405500  42.500000
#             1        34.756000                  0.474120  40.000000
# 8           0        30.693750                  0.526750  49.625000
#             1        32.204545                  0.488682  42.272727
# 9           0        28.840000                  0.311100  46.000000
#             1        33.300000                  0.683778  43.166667
# 10          0        30.114286                  0.411071  43.357143
#             1        31.380000                  0.514500  41.700000
# 11          0        37.125000                  0.259000  40.750000
#             1        39.385714                  0.673143  46.714286
# 12          0        30.560000                  0.301200  48.200000
#             1        34.575000                  0.623250  46.500000
# 13          0        33.280000                  0.405600  46.800000
#             1        36.720000                  0.521000  42.200000
# 14          1        35.100000                  0.312000  42.000000
# 15          1        37.100000                  0.153000  43.000000
# 17          1        40.900000                  0.817000  47.000000

# %% [markdown]
# ### Line plots in pandas

# %%
plot = df[['BMI', 'Glucose']].plot.line()

fig = plot.get_figure()
fig.savefig('pandas_trial_fig.png')

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
from datetime import date, datetime, timedelta
import pandas as pd, numpy as np

# %%
df_temp = pd.read_csv('daily-min-temperatures.csv')
df_temp
# Out:
#             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# ...          ...   ...
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
print(type(df_temp['Date'].iloc[1]))
# Out:
# <class 'str'>

# %%
df_temp = df_temp.set_index('Date')

# %%
df_temp
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
df_temp.index
# Out:
# Index(['1981-01-01', '1981-01-02', '1981-01-03', '1981-01-04', '1981-01-05',
#        '1981-01-06', '1981-01-07', '1981-01-08', '1981-01-09', '1981-01-10',
#        ...
#        '1990-12-22', '1990-12-23', '1990-12-24', '1990-12-25', '1990-12-26',
#        '1990-12-27', '1990-12-28', '1990-12-29', '1990-12-30', '1990-12-31'],
#       dtype='object', name='Date', length=3650)

# %%
print(df_temp.index[1], type(df_temp.index[1]))
# Out:
# 1981-01-02 <class 'str'>

# %%
df_temp_2 = pd.read_csv('daily-min-temperatures.csv')
df_temp_2
# Out:
#             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# ...          ...   ...
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
df_temp_2['Date'] = pd.to_datetime(df_temp_2['Date'])
df_temp_2
# Out:
#            Date  Temp
# 0    1981-01-01  20.7
# 1    1981-01-02  17.9
# 2    1981-01-03  18.8
# 3    1981-01-04  14.6
# 4    1981-01-05  15.8
# ...         ...   ...
# 3645 1990-12-27  14.0
# 3646 1990-12-28  13.6
# 3647 1990-12-29  13.5
# 3648 1990-12-30  15.7
# 3649 1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
print(type(df_temp_2['Date'].iloc[1]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df_temp_2 = df_temp_2.set_index('Date')
print(df_temp_2.index[1], type(df_temp_2.index[1]))
# Out:
# 1981-01-02 00:00:00 <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df_temp_2
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
df_temp_3 = pd.read_csv('daily-min-temperatures.csv')
df_temp_3['Date'] = pd.to_datetime(df_temp_3['Date']).dt.date

df_temp_3 = df_temp_3.set_index('Date')
print(df_temp_3.index[1], type(df_temp_3.index[1]))
# Out:
# 1981-01-02 <class 'datetime.date'>
